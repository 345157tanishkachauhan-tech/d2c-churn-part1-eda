# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries Loaded")
# Out:
# Libraries Loaded

# %%
customers = pd.read_csv("data/customers.csv")
orders = pd.read_csv("data/orders.csv")
tickets = pd.read_csv("data/support_tickets.csv")
web = pd.read_csv("data/web_events_snapshot.csv")
campaigns = pd.read_csv("data/intervention_history.csv")
labels = pd.read_csv("data/churn_labels.csv")
snapshot = pd.read_csv("data/rfm_modeling_snapshot.csv")

print("All files loaded successfully")
# Out:
# All files loaded successfully

# %%
print("Customers:", customers.shape)
print("Orders:", orders.shape)
print("Tickets:", tickets.shape)
print("Web:", web.shape)
print("Campaigns:", campaigns.shape)
print("Labels:", labels.shape)
print("Snapshot:", snapshot.shape)
# Out:
# Customers: (2400, 9)
# Orders: (10009, 10)
# Tickets: (1921, 8)
# Web: (2400, 10)
# Campaigns: (2400, 5)
# Labels: (2400, 4)
# Snapshot: (2400, 29)

# %%
snapshot.columns.tolist()
# Out:
# ['customer_id',
#  'snapshot_date',
#  'city_tier',
#  'age_group',
#  'acquisition_channel',
#  'loyalty_tier',
#  'preferred_category',
#  'marketing_consent',
#  'recency_days',
#  'frequency_180d',
#  'monetary_180d',
#  'return_rate_180d',
#  'avg_discount_pct_180d',
#  'avg_rating_180d',
#  'category_diversity_180d',
#  'ticket_count_90d',
#  'negative_ticket_rate_90d',
#  'avg_resolution_hours_90d',
#  'days_since_signup',
#  'sessions_30d',
#  'product_views_30d',
#  'cart_adds_30d',
#  'wishlist_adds_30d',
#  'abandoned_carts_30d',
#  'email_opens_30d',
#  'campaign_clicks_30d',
#  'last_visit_days_ago',
#  'churn_next_60d',
#  'split']

# %%
df = snapshot.copy()

print(df.shape)
df.head()
# Out:
# (2400, 29)
#   customer_id snapshot_date city_tier age_group acquisition_channel  \
# 0   CUST00001    2025-09-30    Tier 1     18-24           Instagram
# 1   CUST00002    2025-09-30    Tier 2     25-34         Marketplace
# 2   CUST00003    2025-09-30    Tier 1     25-34          Influencer
# 3   CUST00004    2025-09-30    Tier 3     25-34       Google Search
# 4   CUST00005    2025-09-30    Tier 3     35-44             Organic
#
#   loyalty_tier preferred_category marketing_consent  recency_days  \
# 0       Silver             Makeup               Yes           107
# 1       Silver          Hair Care               Yes            40
# 2          NaN          Skin Care               Yes           171
# 3          NaN          Fragrance                No           131
# 4         Gold          Hair Care               Yes            38
#
#    frequency_180d  ...  sessions_30d  product_views_30d  cart_adds_30d  \
# 0               1  ...             1                  4              0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(x='churn_next_60d', data=df)
plt.title("Churn Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='churn_next_60d', y='recency_days', data=df)
plt.title("Recency vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='churn_next_60d', y='frequency_180d', data=df)
plt.title("Frequency vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='churn_next_60d', y='monetary_180d', data=df)
plt.title("Monetary Value vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='churn_next_60d', y='ticket_count_90d', data=df)
plt.title("Support Tickets vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='churn_next_60d', y='sessions_30d', data=df)
plt.title("Sessions vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='churn_next_60d', y='return_rate_180d', data=df)
plt.title("Return Rate vs Churn")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='churn_next_60d', y='campaign_clicks_30d', data=df)
plt.title("Campaign Engagement vs Churn")
plt.show()

# %%
df[['recency_days',
    'frequency_180d',
    'monetary_180d',
    'ticket_count_90d',
    'sessions_30d',
    'return_rate_180d']].describe()
# Out:
#        recency_days  frequency_180d  monetary_180d  ticket_count_90d  \
# count   2400.000000     2400.000000    2400.000000       2400.000000
# mean      87.375833        1.594583    1179.763196          0.229167
# std       80.137473        1.184964    1035.900649          0.471779
# min        0.000000        0.000000       0.000000          0.000000
# 25%       25.000000        1.000000     449.270000          0.000000
# 50%       66.000000        1.000000     911.875000          0.000000
# 75%      129.000000        2.000000    1681.510000          0.000000
# max      562.000000        8.000000    6982.410000          3.000000
#
#        sessions_30d  return_rate_180d
# count   2400.000000       2400.000000
# mean       5.460000          0.061505
# std        4.400167          0.203092
# min        0.000000          0.000000
# 25%        2.000000          0.000000
# 50%        5.000000          0.000000
# 75%        8.000000          0.000000
# ...

# %%
summary.to_csv("summary_statistics.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 summary.to_csv("summary_statistics.csv")
#
# NameError: name 'summary' is not defined

# %%
summary = df[['recency_days',
              'frequency_180d',
              'monetary_180d',
              'ticket_count_90d',
              'sessions_30d',
              'return_rate_180d']].describe()

summary
# Out:
#        recency_days  frequency_180d  monetary_180d  ticket_count_90d  \
# count   2400.000000     2400.000000    2400.000000       2400.000000
# mean      87.375833        1.594583    1179.763196          0.229167
# std       80.137473        1.184964    1035.900649          0.471779
# min        0.000000        0.000000       0.000000          0.000000
# 25%       25.000000        1.000000     449.270000          0.000000
# 50%       66.000000        1.000000     911.875000          0.000000
# 75%      129.000000        2.000000    1681.510000          0.000000
# max      562.000000        8.000000    6982.410000          3.000000
#
#        sessions_30d  return_rate_180d
# count   2400.000000       2400.000000
# mean       5.460000          0.061505
# std        4.400167          0.203092
# min        0.000000          0.000000
# 25%        2.000000          0.000000
# 50%        5.000000          0.000000
# 75%        8.000000          0.000000
# ...

# %%
summary.to_csv("summary_statistics.csv")

# %%
[col for col in snapshot.columns if 'churn' in col.lower()]
# Out:
# ['churn_next_60d']
